# %% [markdown]
# # Machine Learning Lab 2 - Statistical Inferences and Exploratory Data Analysis
# Submitted By <br/>
# Name: **Jortin Paul** <br/>
# Register Number: **19112010** <br/>
# Class: **5 BSc Data Science** <br/>
#
# <hr/>
#
# ## 1. Lab Overview
#
# #### Objectives
# - To understand the trend of exam scores of students based on their background details
# - To find new fetaures and hidden patterns that affects the scores of the students
# - To provide a solution on how to improve the scores
# - To find intresting patterns as a Data Analyst that can replace basic statistical measures
#
# #### Problem Definition
# As all the ML libraries were installed and verified during previous lab session we can move forward without any further preprocesses for Explorartory Data Analysis.
# To achieve the objectives such as analyse and find the trends of the exam scores we can use python and the libraries such as pandas,matplotlib and seaborn.
#
# #### Approach
# The ExamResult data which is already provided can be analysed using python through jupyter notebook with the libraries that are already intsalled.A statistical approach has been used to find the hidden features using python language.
#
# Using Pandas to import the Dataset and visualizations can be done through matplotlib and seaborn libraries
#
# #### Sections
# 1. Lab Overview
# 1. Theoretical Background
#    1. What is Exploratory Data Analysis
#    1. Classification of Exploratory Data Analysis
#       1. Univariate graphical
#       1. Multivariate graphical
#       1. Univariate non-graphical
#       1. Multivariate non-graphical
# 1. Data Overview
# 1. Exploratory Data Analysis
#    1. Import Libraries
#    1. Load the Data
#    1. Understand the Data
#    1. Feature Extraction
#    1. Discriptive Statistics
#    1. More Into the Data Set
#    1. Export the Data
# 1. Results
# 1. Observations
# 1. Conclusion
# 1. Future Enhancement
#
# #### References
# 1. https://www.analyticsvidhya.com/blog/2021/05/exploratory-data-analysis-eda-a-step-by-step-guide/
# 1. https://www.itl.nist.gov/div898/handbook/eda/section1/eda11.htm
# 1. https://analyticsindiamag.com/exploratory-data-analysis-functions-types-tools/
#
# <hr/>

# %% [markdown]
# ## 2. Theoretical Background

# %% [markdown]
# ### A. What is Exploratory Data Analysis
# Exploratory Data Analysis, or EDA one of the important step in any Data Analysis is the process of investigating the dataset to discover patterns, and anomalies (outliers), and to form hypotheses based on our understanding of the dataset.
#
# EDA involves processes like generating summary statistics for numerical data in the dataset, creating various graphical representations to understand the data better etc. or
#
# Exploratory Data Analysis is an approach for data analysis that employs a variety of techniques to:
# 1. get maximize insight from a data set
# 1. uncover underlying structure
# 1. extract important variables
# 1. detect outliers and anomalies
# 1. test underlying assumptions

# %% [markdown]
# ### B. Classification of Exploratory Data Analysis
# EDA techniques are either graphical or quantitative (non-graphical).
#
# Graphical methods involve summarising the data in a diagrammatic or visual way while the quantitative method, on the other hand, involves the calculation of summary statistics.
#
# These two types of methods are further divided into univariate and multivariate methods. Univariate methods consider one variable (data column) at a time, while multivariate methods consider two or more variables at a time to explore relationships.
#
# Thus, there are four types of EDA in all:
# 1. Univariate non-graphical
# 1. Multivariate non-graphical
# 1. Univariate graphical
# 1. Multivariate graphical
#
# The graphical methods provide more **subjective analysis** and quantitative methods are more **objective**.

# %% [markdown]
# #### a. Univariate non-graphical:
# This is the simplest form of data analysis among the four as in this type of analysis, the data that is being analysed consists of just a single variable. The main purpose of this analysis is to describe the data and to find patterns.
#
# #### b. Multivariate non-graphical:
# The multivariate non-graphical type of EDA generally depicts the relationship between multiple variables of data through
# cross tabulation or statistics.
#
# #### c. Univariate graphical:
# Unlike the non-graphical method, the graphical method provides the full picture of the data.
#
# The three main methods of analysis under this type are:
# 1. Histogram : represents the total count of cases for a range of values
# 1. Stem and leaf plot : hows the shape of the distribution along with data values
# 1. Box plots : graphically depict a summary of minimum, first quartile median, third quartile, and maximum
#
# #### d. Multivariate graphical:
# This type of EDA displays the relationship between two or more set of data. A bar chart, where each group represents a level of one of the variables and each bar within the group represents levels of other variables.
#
# Few of the main visualization methods are:
# 1. Scatter plot: uses dots to represent the values obtained for two different variables along the x-axis and y-axis
# 1. Bar chart: represents categorical data, with rectangular bars having lengths proportional to the values that they represent

# %% [markdown]
# ## 3. Data Overview
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **ExamResults** is a dataset of size **30 kb** that contains the data of **500** students in an University.
#
# The data has 8 attributes that gives informations of Students such as:
# 1. Sex : The gender of the Student
# 2. Country : The Country that Student belongs to
# 3. ParentEductaion : The maximum Educational Qualification of the Parent
# 4. FinancialAid : The student has Financial Aid or not
# 5. TestPreparation : The preparation level of Student
# 6. Science : Score achieved in Science
# 7. Language : Score achieved in Language
# 8. Communication : Score achieved in Communication

# %% [markdown]
# ## 4. Exploratory Data Analysis

# %% [markdown]
# ### A. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### B. Load the Data

# %%
# Assigning the data set a dataframe
df= pd.read_csv('C:/Users/JORTIN PAUL/Documents/PROJECTS/SEM 5/Machine Learning/ExamResults.csv')

# %% [markdown]
# ### C. Understand the Data

# %%
# Print first 5 rows of the dataframe
df.head()
# Out:
#     Sex Country     ParentEducation   FinancialAid TestPreparation  Science  \
# 0  Girl      UK   bachelor's degree  No Assistance         Minimum       75
# 1  Girl     USA        some college  No Assistance        Thorough       72
# 2  Girl      UK     master's degree  No Assistance         Minimum       93
# 3   Boy   India  associate's degree       Assisted         Minimum       50
# 4   Boy     USA        some college  No Assistance         Minimum       79
#
#    Language  Communcation
# 0        74            75
# 1        92            89
# 2        97            94
# 3        59            45
# 4        80            76

# %%
# Print last 5 rows of the dataframe
df.tail()
# Out:
#       Sex    Country   ParentEducation   FinancialAid TestPreparation  \
# 494  Girl         UK       high school  No Assistance         Minimum
# 495   Boy  Australia       high school  No Assistance        Thorough
# 496  Girl        USA      some college  No Assistance         Minimum
# 497  Girl  Australia      some college       Assisted        Thorough
# 498  Girl         UK  some high school  No Assistance         Minimum
#
#      Science  Language  Communcation
# 494       57        66            69
# 495       71        66            67
# 496       57        50            53
# 497       62        80            77
# 498       69        71            69

# %%
# Shape of the dataframe
df.shape
# Out:
# (499, 8)

# %% [markdown]
# we have 499 rows and 8 columns

# %%
# Summary of dataframe 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Sex              499 non-null    object
#  1   Country          499 non-null    object
#  2   ParentEducation  499 non-null    object
#  3   FinancialAid     499 non-null    object
#  4   TestPreparation  499 non-null    object
#  5   Science          499 non-null    int64
#  6   Language         499 non-null    int64
#  7   Communcation     499 non-null    int64
# dtypes: int64(3), object(5)
# memory usage: 31.3+ KB

# %%
# Columns of the dataframe
df.columns
# Out:
# Index(['Sex', 'Country', 'ParentEducation', 'FinancialAid', 'TestPreparation',
#        'Science', 'Language', 'Communcation'],
#       dtype='object')

# %%
# Check for null values for Data Cleaning
df.isnull().sum()
# Out:
# Sex                0
# Country            0
# ParentEducation    0
# FinancialAid       0
# TestPreparation    0
# Science            0
# Language           0
# Communcation       0
# dtype: int64

# %%
# Checking for null values graphicaly
sns.heatmap(df.isnull(),yticklabels=False,cmap='flare')
# Out:
# <AxesSubplot:>

# %% [markdown]
# As we don't have any **null values** in our data set we can proceed with the Analysis

# %%
# Statistical summary of the dataframe
df.describe()
# Out:
#           Science    Language  Communcation
# count  499.000000  499.000000    499.000000
# mean    68.655311   70.434870     68.234469
# std     14.966275   14.664291     15.187950
# min      3.000000   19.000000     11.000000
# 25%     60.000000   60.000000     58.000000
# 50%     69.000000   71.000000     69.000000
# 75%     79.000000   81.000000     79.000000
# max    100.000000   99.000000     99.000000

# %%
# Full summary statistics(Including the categorical value)
df.describe(include='all')
# Out:
#         Sex Country     ParentEducation   FinancialAid TestPreparation  \
# count   499     499                 499            499             499
# unique    2       5                   6              2               2
# top     Boy     USA  associate's degree  No Assistance         Minimum
# freq    253     166                 120            327             328
# mean    NaN     NaN                 NaN            NaN             NaN
# std     NaN     NaN                 NaN            NaN             NaN
# min     NaN     NaN                 NaN            NaN             NaN
# 25%     NaN     NaN                 NaN            NaN             NaN
# 50%     NaN     NaN                 NaN            NaN             NaN
# 75%     NaN     NaN                 NaN            NaN             NaN
# max     NaN     NaN                 NaN            NaN             NaN
#
#            Science    Language  Communcation
# count   499.000000  499.000000    499.000000
# ...

# %%
# Unique values of each columns
df.nunique()
# Out:
# Sex                 2
# Country             5
# ParentEducation     6
# FinancialAid        2
# TestPreparation     2
# Science            70
# Language           67
# Communcation       72
# dtype: int64

# %%
# Unique values in Sex column
df['Sex'].unique()
# Out:
# array(['Girl', 'Boy'], dtype=object)

# %% [markdown]
# Girl and Boy are the Categories in Sex

# %%
# Unique values in Country
df['Country'].unique()
# Out:
# array(['UK', 'USA', 'India', 'Australia', 'Others'], dtype=object)

# %% [markdown]
# UK,USA,India and Australia are the Main countries from which students are from

# %%
# Unique values in ParentEductaion
df['ParentEducation'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %% [markdown]
# Almost every parents have some educational background from some Highschool till Master's degree

# %%
# Unique values in FinancialAid
df['FinancialAid'].unique()
# Out:
# array(['No Assistance', 'Assisted'], dtype=object)

# %% [markdown]
# Whether the students are Financially assisted or not

# %%
# Unique values in TestPreparation
df['TestPreparation'].unique()
# Out:
# array(['Minimum', 'Thorough'], dtype=object)

# %% [markdown]
# The prepartaion level of Students is either Thoroughly or at Minimum level

# %%
# check for any duplicate row in the dataframe
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### D. Feature Extraction

# %%
# Creating a new cloumn having the sum of total marks of subjects
df["TotalMarks"] = df["Science"] + df["Language"] + df["Communcation"]

# %%
df.head()
# Out:
#     Sex Country     ParentEducation   FinancialAid TestPreparation  Science  \
# 0  Girl      UK   bachelor's degree  No Assistance         Minimum       75
# 1  Girl     USA        some college  No Assistance        Thorough       72
# 2  Girl      UK     master's degree  No Assistance         Minimum       93
# 3   Boy   India  associate's degree       Assisted         Minimum       50
# 4   Boy     USA        some college  No Assistance         Minimum       79
#
#    Language  Communcation  TotalMarks
# 0        74            75         224
# 1        92            89         253
# 2        97            94         284
# 3        59            45         154
# 4        80            76         235

# %% [markdown]
# The Total Marks has been calculated of each student by summing the scores of Science,Language and Communication.
#
# The Total Marks is out of 300

# %%
# Binning the TotalMarks
bins = np.linspace(min(df["TotalMarks"]),max(df["TotalMarks"]),4)
group_names=["Low","Average","High"]
df["Performance"]=pd.cut(df["TotalMarks"],bins,labels=group_names)

# %%
df.tail()
# Out:
#       Sex    Country   ParentEducation   FinancialAid TestPreparation  \
# 494  Girl         UK       high school  No Assistance         Minimum
# 495   Boy  Australia       high school  No Assistance        Thorough
# 496  Girl        USA      some college  No Assistance         Minimum
# 497  Girl  Australia      some college       Assisted        Thorough
# 498  Girl         UK  some high school  No Assistance         Minimum
#
#      Science  Language  Communcation  TotalMarks Performance
# 494       57        66            69         192     Average
# 495       71        66            67         204     Average
# 496       57        50            53         160     Average
# 497       62        80            77         219        High
# 498       69        71            69         209     Average

# %% [markdown]
# The total students has been Categorized into 3 based on the marks that they have achieved:
# 1. Low
# 1. Average
# 1. High

# %%
#Calculate Percentage of Studnents
df["TotalPercentage"] = (df["TotalMarks"]/300)*100
df['TotalPercentage'] = df['TotalPercentage'].astype(int)

# %%
#Calculate Grades of Students
def grade(scores):
    if scores >=85 and scores <=100:
        return 'A'
    elif scores >=70 and scores <=85:
        return 'B'
    elif scores >=55 and scores <=70:
        return 'C'
    elif scores >=35 and scores <=55:
        return 'D'
    elif scores >=0 and scores <=35:
        return 'E'
df['Grades']=df['TotalPercentage'].apply(grade)

# %% [markdown]
# Grades has been calculated based on the Marks that they have achieved:
# 1. A
# 2. B
# 3. C
# 4. D
# 5. E

# %%
df.head()
# Out:
#     Sex Country     ParentEducation   FinancialAid TestPreparation  Science  \
# 0  Girl      UK   bachelor's degree  No Assistance         Minimum       75
# 1  Girl     USA        some college  No Assistance        Thorough       72
# 2  Girl      UK     master's degree  No Assistance         Minimum       93
# 3   Boy   India  associate's degree       Assisted         Minimum       50
# 4   Boy     USA        some college  No Assistance         Minimum       79
#
#    Language  Communcation  TotalMarks Performance  TotalPercentage Grades
# 0        74            75         224        High               74      B
# 1        92            89         253        High               84      B
# 2        97            94         284        High               94      A
# 3        59            45         154     Average               51      D
# 4        80            76         235        High               78      B

# %% [markdown]
# ### E. Descriptive Statistics

# %% [markdown]
# #### Correlation

# %%
df.corr()
# Out:
#                   Science  Language  Communcation  TotalMarks  TotalPercentage
# Science          1.000000  0.824008      0.806071    0.920456         0.920726
# Language         0.824008  1.000000      0.952786    0.971411         0.971116
# Communcation     0.806071  0.952786      1.000000    0.965702         0.965203
# TotalMarks       0.920456  0.971411      0.965702    1.000000         0.999816
# TotalPercentage  0.920726  0.971116      0.965203    0.999816         1.000000

# %%
# Graphically represnting the correlation between the variables
corr = df.corr()
sns.heatmap(corr,annot=True,cmap='inferno')
# Out:
# <AxesSubplot:>

# %%
sns.regplot(x="Science",y="TotalMarks",data=df)
plt.ylim(0,)
# Out:
# (0.0, 310.41156943381884)

# %%
sns.regplot(x="Communcation",y="TotalMarks",data=df)
plt.ylim(0,)
# Out:
# (0.0, 310.2)

# %%
sns.regplot(x="Language",y="TotalMarks",data=df)
plt.ylim(0,)
# Out:
# (0.0, 310.2)

# %% [markdown]
#  From above graphs it is clear that there is a **Positive correlation** between every variables

# %% [markdown]
# #### Covariance

# %%
# Covariance of columns
df.cov()
# Out:
#                     Science    Language  Communcation   TotalMarks  \
# Science          223.989384  180.844975    183.225560   588.059919
# Language         180.844975  215.041432    212.205061   608.091468
# Communcation     183.225560  212.205061    230.673830   626.104450
# TotalMarks       588.059919  608.091468    626.104450  1822.255837
# TotalPercentage  196.060965  202.618494    208.576233   607.255692
#
#                  TotalPercentage
# Science               196.060965
# Language              202.618494
# Communcation          208.576233
# TotalMarks            607.255692
# TotalPercentage       202.438749

# %% [markdown]
# #### Value Counts

# %% [markdown]
# #### Sex

# %%
df['Sex'].value_counts()
# Out:
# Boy     253
# Girl    246
# Name: Sex, dtype: int64

# %%
plt.figure(figsize=(10,8))
df['Sex'].value_counts().plot.pie(autopct='%1.1f%%').set_title('Gender Divison')
plt.show()

# %% [markdown]
# Result:
# 1. Total Number of Students : 499
# 1. Number of Boys : 253
# 1. Number of Girls : 246
#
# Number of Boys is slightly greater than Girls

# %% [markdown]
# #### Country

# %%
df['Country'].value_counts()
# Out:
# USA          166
# Australia    127
# UK            99
# Others        64
# India         43
# Name: Country, dtype: int64

# %%
plt.figure(figsize=(10,8))
df['Country'].value_counts().plot.pie(autopct='%1.1f%%').set_title('Country')
plt.show()

# %% [markdown]
# Result:
# 1. Students from USA : 166
# 1. Students from Australia : 127
# 1. Students from UK : 99
# 1. Students from India : 43
# 1. Students from Other Countries: 64
#
# USA is the major country from which students are from and Inida is the least

# %% [markdown]
# #### ParentEducation

# %%
df['ParentEducation'].value_counts()
# Out:
# associate's degree    120
# some college          115
# some high school       91
# high school            88
# bachelor's degree      58
# master's degree        27
# Name: ParentEducation, dtype: int64

# %%
plt.figure(figsize=(10,8))
df['ParentEducation'].value_counts().plot.pie(autopct='%1.1f%%').set_title('Education of Parents')
plt.show()

# %% [markdown]
# Result:
# 1. associate's degree :   120
# 1. some college       :   115
# 1. some high school   :   91
# 1. high school        :   88
# 1. bachelor's degree  :   58
# 1. master's degree    :   27
#
# A trend could be seen that parents going for further education is less as only 27 parents have Master degreee but a good amount of parents have associate's degree as well

# %% [markdown]
# #### FinancialAid

# %%
df['FinancialAid'].value_counts()
# Out:
# No Assistance    327
# Assisted         172
# Name: FinancialAid, dtype: int64

# %%
plt.figure(figsize=(10,8))
df['FinancialAid'].value_counts().plot.pie(autopct='%1.1f%%').set_title('Fiancial Aid for Students')
plt.show()

# %% [markdown]
# Result:
# 1. No Assistance :    327
# 1. Assisted :         172
#
# Only a one fourth of students is Financilay Assisted

# %% [markdown]
# #### TestPreparation

# %%
df['TestPreparation'].value_counts()
# Out:
# Minimum     328
# Thorough    171
# Name: TestPreparation, dtype: int64

# %%
plt.figure(figsize=(10,8))
df['TestPreparation'].value_counts().plot.pie(autopct='%1.1f%%').set_title('Test Preparation of Students')
plt.show()

# %% [markdown]
# Result:
# 1. Minimum  :   328
# 1. Thorough  :  171
#
# Only a One fourth of students has been throughly prepared for the test

# %% [markdown]
# #### Performance

# %%
df['Performance'].value_counts()
# Out:
# High       254
# Average    231
# Low         13
# Name: Performance, dtype: int64

# %%
plt.figure(figsize=(10,8))
df['Performance'].value_counts().plot.pie(autopct='%1.1f%%').set_title('Performance Based on the Total Marks')
plt.show()

# %% [markdown]
# Result:
# 1. High :       254
# 1. Average :    231
# 1. Low :         13
#
# Most of the Students Has Higher Marks and Only a least Studenst has Low Marks

# %% [markdown]
# #### Grades

# %%
df['Grades'].value_counts()
# Out:
# B    191
# C    157
# D     78
# A     63
# E     10
# Name: Grades, dtype: int64

# %%
plt.figure(figsize=(10,8))
df['Grades'].value_counts().plot.pie(autopct='%1.1f%%').set_title('Grades Based on the Total Marks')
plt.show()

# %% [markdown]
# Result
# 1. A     63
# 1. B    191
# 1. C    157
# 1. D     78
# 1. E     10
#
# Most of the Students have B and C grade and only 10 students has E grades

# %% [markdown]
# ### F. More Into the Data Set

# %%
plt.figure(figsize = [15,8])
sns.countplot(x = 'Sex', hue = "Country", palette = "spring", alpha = 0.7, data = df)
plt.title('Students and Country Based on Gender Division')
sns.despine()

# %% [markdown]
# Result:
#
# Most of the Boys are from USA and least are from India same in the case of Girls as well

# %%
plt.figure(figsize = [15,8])
sns.countplot(x = 'Sex', hue = "FinancialAid", palette = "ocean", alpha = 0.7, data = df)
plt.title('Students and Financial Aid Based on Gender Divsion')
sns.despine()

# %% [markdown]
# Result:
#
# Comparitevly both Boys and Girls are equally Financially Assisted while there is a light increase in Boys section who has not any Assistance than Girls

# %%
plt.figure(figsize = [15,8])
sns.countplot(x = 'FinancialAid', hue = "ParentEducation", palette = "ocean_r", alpha = 0.7, data = df)
plt.title('Parents Eductaion and Based on Financial Aid')
sns.despine()

# %% [markdown]
# Result:
#
# Financial Assistance are given more to the Students whose parents have Associate Degree and Some college while Students whose parents have Master Degree has least Financilay Assited

# %%
plt.figure(figsize = [15,8])
sns.countplot(x = 'FinancialAid', hue = "TestPreparation", palette = "rocket", alpha = 0.7, data = df)
plt.title('Students Test Preparation Based on the Financial Aid ')
sns.despine()

# %% [markdown]
# Students who have Throughly prepared for exams are from Non Financialy assited group

# %%
plt.figure(figsize = [15,8])
sns.countplot(x = 'Sex', hue = "Performance", palette = "spring", alpha = 0.7, data = df)
plt.title('Students Performance Based on Gender Division')
sns.despine()

# %% [markdown]
# Girls have Higher Marks than Boys and most of the Boys belong to Average Category

# %%
plt.figure(figsize = [15,8])
sns.countplot(x = 'Sex', hue = "Grades", palette = "ocean", alpha = 0.7, data = df)
plt.title('Students Gardes Based on Gender Divsion')
sns.despine()

# %% [markdown]
# Girls have more A and E grades than boys

# %%
plt.figure(figsize = [15,8])
sns.countplot(x = 'Country', hue = "Performance", palette = "rocket", alpha = 0.7, data = df)
plt.title('Students Performance and Country')
sns.despine()

# %% [markdown]
# Students from USA has Higher Marks while Students from other Countires has Lower marks and UK as well as India has More number of Average Marks Students

# %%
plt.figure(figsize = [15,8])
sns.countplot(x = 'Country', hue = "Grades", palette = "ocean", alpha = 0.7, data = df)
plt.title('Students Gardes Based on Country')
sns.despine()

# %% [markdown]
# India has least A grades while USA has highest A grades

# %%
plt.figure(figsize = [15,8])
sns.countplot(x = 'ParentEducation', hue = "Performance", palette = "rocket", alpha = 0.7, data = df)
plt.title('Students Performance and Parents Education')
sns.despine()

# %% [markdown]
# Students whose Parents have Master's degree and Bachelor's degree does'nt have low marks

# %%
sns.factorplot(x ='Country', y ='Science', data = df, kind ='bar',hue='Sex')
plt.title('Students Country and Science Marks')
plt.figure(figsize=(15,8))

# %% [markdown]
# Boys and Girls from India have lesser marks in Science while Other Countries Students have higher Marks

# %%
sns.factorplot(x ='Country', y ='Communcation', data = df, kind ='bar',hue='Sex')
plt.title('Students Country and Communication Marks')
plt.figure(figsize=(15,8))

# %% [markdown]
# Boys and Girls from India have lesser marks in Communication while Othe Country Students have Higher Marks

# %%
sns.factorplot(x ='Country', y ='Language', data = df, kind ='bar',hue='Sex')
plt.title('Students Country and Language Marks')
plt.figure(figsize=(15,8))

# %% [markdown]
# Boys and Girls from India have lesser marks in Language while Othe Country Students have Higher Marks

# %%
df.groupby('Sex')['Science','Communcation','Language'].sum().plot.bar()
plt.title('Score Based on each Subject under Gender Divison')
plt.legend()
plt.show()

# %% [markdown]
# Boys are more good at Science while Girls are good at Languages
# Boys has least marks at Communication and Girls have it at Science

# %%
sns.factorplot(x ='Sex', y ='TotalMarks', data = df, kind ='bar',hue='TestPreparation')
plt.title('Students Test Prepartaion and Total Marks')
plt.figure(figsize=(15,8))

# %% [markdown]
# Girls are the one who has througly and Mimumly more prepared for exams than boys

# %% [markdown]
# ### G. Export the Data

# %%
# For Future purposes Export the Data
df.to_csv('C:/Users/JORTIN PAUL/Documents/PROJECTS/SEM 5/Machine Learning/ExamResultsnew.csv')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 5. Results
# 1. ExamResult is a clean Data set as we didn't had have any null values
# 1. Positive correlation is visible between every variables
# 1. Number of Boys is slightly greater than Girls in the University
#    1. Most of the Boys and Girls are from USA and least are from India
#    1. Boys and Girls are equally Financially Assisted
# 1. USA is the major country from which students are from and Inida is the least
# 1. Large amount of parents have associate's degree while Master's Degree is the least
#    1. Students whose Parents have Master's degree and Bachelor's degree does'nt have low marks
# 1. Only a one fourth of students is Financilay Assisted
#    1. Financial Assistance are given more to the Students whose parents have Master Degree
#    1. Students who have Throughly prepared for exams are from Non Financialy assited group
# 1. Only a One fourth of students has been throughly prepared for the test as well
#    1. Girls are the one who has througly and Mimumly more prepared for exams than boys
# 1. Most of the Students Has Higher Marks and Only a least Studenst has Low Marks
#    1. Girls have Higher Marks than Boys and most of the Boys belong to Average Category
#    1. Students from USA has Higher Marks while Students from other Countires has Lower marks
#    1. UK as well as India has More number of Average Marks Students
# 1. Most of the Students have B and C grade and only 10 students has E grades
#    1. Girls have more A and E grades than boys
#    1. India has least A grades while USA has highest A grades
# 1. Boys are more good at Science while Girls are good at Languages
# 1. Boys has least marks at Communication and Girls have it at Science
#    1. Boys and Girls from India have lesser marks in Science while Other Countries Students have higher Marks in it
#    1. Boys and Girls from India have lesser marks in Communication while Othe Country Students have Higher Marks in it
#    1. Boys and Girls from India have lesser marks in Language while Othe Country Students have Higher Marks in it

# %% [markdown]
# ## 6. Observations
# 1. Most of the Students belongs to Average Category
# 1. Revision method should be increased as most of the students doesn't prepare well for the exams especially boys
#    1. Financialy assisted students dose'nt Throughly prepare for exams as well, which adds more weightage to the above statement
# 1. Girls should be given more concentration at Science while Boys at Communication
# 1. A less Amount of students only requires more support
# 1. Students from India has lesser marks compared to other Countires, so Imporve the method of teaching Science,Communication and Languages
#    1. India has more Average Students which supports the above statement
# 1. Students from Other Countires also require attention
#
# 1. Intresting Observation:
#    1. Students whose Parents have Master's degree and Bachelor's degree does'nt have low marks which means Students of those parents are seroious about their studies and knows the importance of education

# %% [markdown]
# ## 7. Conclusion
#
# As a Data Analyst I  would suggest to go through the above observations and take necesary actions to imporve the scores of students and give more attention to the students which has been mentioned above.
#
# In the lab **Statistical Inferences and Exploratory Data Analysis** I have tried to understand the uses  of few libraries that are used in this Data Analysis in addition I could understand how a small data set can give these much of insights.
